# %%
import pandas as pd
import numpy as np

# %%
t=(10,11,12)
s=pd.Series(t)
s
# Out:
# 0    10
# 1    11
# 2    12
# dtype: int64

# %%
d=pd.Series(np.arange(10))
d
d[1:5]
# Out:
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int32

# %%
d=pd.Series(np.arange(11,20))
d[1:5]
# Out:
# 1    12
# 2    13
# 3    14
# 4    15
# dtype: int32

# %%
#dataframe using a list
data=[['a',1],['b',2],['c',3],['d',"A"],['e',10.4]]
df=pd.DataFrame(data)
df
# Out:
#    0     1
# 0  a     1
# 1  b     2
# 2  c     3
# 3  d     A
# 4  e  10.4

# %%
df=pd.DataFrame(data,columns=["Letter","Numbers"])
df
# Out:
#   Letter Numbers
# 0      a       1
# 1      b       2
# 2      c       3
# 3      d       A
# 4      e    10.4

# %%
df=pd.DataFrame(data, columns=["letter","Numbers"],index=["A","B","C","D","E"])

# %%
df
# Out:
#   letter Numbers
# A      a       1
# B      b       2
# C      c       3
# D      d       A
# E      e    10.4

# %%
#dataframe using a dictionary
data={'Name':['a','b','c','d','e'],'Age':[22,23,12,44,25]}
data
# Out:
# {'Name': ['a', 'b', 'c', 'd', 'e'], 'Age': [22, 23, 12, 44, 25]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#   Name  Age
# 0    a   22
# 1    b   23
# 2    c   12
# 3    d   44
# 4    e   25

# %%
df=pd.DataFrame(data, index=['A','B','C','D','E'])

# %%
df
# Out:
#   Name  Age
# A    a   22
# B    b   23
# C    c   12
# D    d   44
# E    e   25

# %%
df.columns=["Nameof Student","Age of Student"]
df
# Out:
#   Nameof Student  Age of Student
# A              a              22
# B              b              23
# C              c              12
# D              d              44
# E              e              25

# %%
df1=df.rename({"candidate":"Name of the Student"})
df1
# Out:
#   Nameof Student  Age of Student
# A              a              22
# B              b              23
# C              c              12
# D              d              44
# E              e              25

# %%
pwd
# Out:
# 'C:\\Users\\Sanyukta_Gavane'

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#      Gender   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name  Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 876          877         0       3
# 877          878         0       3
# 878          879         0       3
# 879          880         1       1
# 880          881         1       2
# 881          882         0       3
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                               Name  Gender   Age  SibSp  \
# 876                  Gustafsson, Mr. Alfred Ossian    male  20.0      0
# 877                           Petroff, Mr. Nedelio    male  19.0      0
# 878                             Laleff, Mr. Kristo    male   NaN      0
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Gender'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Pclass
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Age'].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8], dtype=int64)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Gender       891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
#statistics of numerical data
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include='O')
# Out:
#                            Name Gender  Ticket    Cabin Embarked
# count                       891    891     891      204      889
# unique                      891      2     681      147        3
# top     Braund, Mr. Owen Harris   male  347082  B96 B98        S
# freq                          1    577       7        4      644

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df['Age']==80
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df.loc[df['Age']<30]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[df['Pclass']<3]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 9             10         1       2
# 11            12         1       1
# ..           ...       ...     ...
# 880          881         1       2
# 883          884         0       2
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[(df['Gender']=='female') & (df['Pclass']==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# ..           ...       ...     ...
# 856          857         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
# 887          888         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[:,0:2]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [891 rows x 2 columns]

# %%
df.iloc[5:10,0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name
# 5                                   Moran, Mr. James
# 6                            McCarthy, Mr. Timothy J
# 7                     Palsson, Master. Gosta Leonard
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                Nasser, Mrs. Nicholas (Adele Achem)

# %%
df.iloc[1:2,0:13]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            2         1       1
#
#                                                 Name  Gender   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C

# %%
df.iloc[4:6,:]
# Out:
#    PassengerId  Survived  Pclass                      Name Gender   Age  \
# 4            5         0       3  Allen, Mr. William Henry   male  35.0
# 5            6         0       3          Moran, Mr. James   male   NaN
#
#    SibSp  Parch  Ticket    Fare Cabin Embarked
# 4      0      0  373450  8.0500   NaN        S
# 5      0      0  330877  8.4583   NaN        Q

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Cabin.value_counts()
# Out:
# B96 B98        4
# G6             4
# C23 C25 C27    4
# C22 C26        3
# F33            3
#               ..
# E34            1
# C7             1
# C54            1
# E36            1
# C148           1
# Name: Cabin, Length: 147, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df1=df.loc[df(['Age']65)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df1=df.loc[df(['Age']>65)]
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
df.Age.median()
# Out:
# 28.0

# %%
df.Age.mode()
# Out:
# 0    24.0
# Name: Age, dtype: float64

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['DS']='Data Science'

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'DS'],
#       dtype='object')

# %%
df1=df.drop(['Name'],axis=1,inplace=False)
print(df1.columns)
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Gender', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked', 'DS'],
#       dtype='object')
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'DS'],
#       dtype='object')

# %%
df2=df.drop(['Embarked'],axis=1,inplace=False)
print(df2.columns)
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'DS'],
#       dtype='object')
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Gender', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'DS'],
#       dtype='object')

# %%
df=pd.read_csv('train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Family']=df['SibSp']+df['Parch']

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Name', 'Gender', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Family'],
#       dtype='object')

# %%
df.sort_values('SibSp')
# Out:
#      PassengerId  Survived                               Name  Gender   Age  \
# 445          446         1          Dodge, Master. Washington    male   4.0
# 534          535         0                Cacic, Miss. Marija  female  30.0
# 535          536         1             Hart, Miss. Eva Miriam  female   7.0
# 536          537         0  Butt, Major. Archibald Willingham    male  45.0
# 537          538         1                LeRoy, Miss. Bertha  female  30.0
# ..           ...       ...                                ...     ...   ...
# 180          181         0       Sage, Miss. Constance Gladys  female   NaN
# 863          864         0  Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# 201          202         0                Sage, Mr. Frederick    male   NaN
# 159          160         0         Sage, Master. Thomas Henry    male   NaN
# 792          793         0            Sage, Miss. Stella Anna  female   NaN
#
#      SibSp  Parch        Ticket      Fare Cabin  Family
# ...

# %%
df
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
df1=df.sort_values('SibSp',ascending=False,ignore_index=True)

# %%
df
# Out:
#      PassengerId  Survived                                               Name  \
# 0              1         0                            Braund, Mr. Owen Harris
# 1              2         1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2              3         1                             Heikkinen, Miss. Laina
# 3              4         1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4              5         0                           Allen, Mr. William Henry
# ..           ...       ...                                                ...
# 886          887         0                              Montvila, Rev. Juozas
# 887          888         1                       Graham, Miss. Margaret Edith
# 888          889         0           Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1                              Behr, Mr. Karl Howell
# 890          891         0                                Dooley, Mr. Patrick
#
# ...

# %%
df.groupby(df['Name']).count()
# Out:
#                                        PassengerId  Survived  Gender  Age  \
# Name
# Abbing, Mr. Anthony                              1         1       1    1
# Abbott, Mr. Rossmore Edward                      1         1       1    1
# Abbott, Mrs. Stanton (Rosa Hunt)                 1         1       1    1
# Abelson, Mr. Samuel                              1         1       1    1
# Abelson, Mrs. Samuel (Hannah Wizosky)            1         1       1    1
# ...                                            ...       ...     ...  ...
# de Mulder, Mr. Theodore                          1         1       1    1
# de Pelsmaeker, Mr. Alfons                        1         1       1    1
# del Carlo, Mr. Sebastiano                        1         1       1    1
# van Billiard, Mr. Austin Blyler                  1         1       1    1
# van Melkebeke, Mr. Philemon                      1         1       1    0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Name         891 non-null    object
#  3   Gender       891 non-null    object
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Family       891 non-null    int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df.Age.isna().sum()
# Out:
# 177

# %%
df.Age.fillna(df.Age.mean(),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Name         891 non-null    object
#  3   Gender       891 non-null    object
#  4   Age          891 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Family       891 non-null    int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
df.Age.isna().sum()
# Out:
# 0

# %%
df.Age=df.Age.astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Name         891 non-null    object
#  3   Gender       891 non-null    object
#  4   Age          891 non-null    int32
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    object
#  8   Fare         891 non-null    float64
#  9   Cabin        204 non-null    object
#  10  Family       891 non-null    int64
# dtypes: float64(1), int32(1), int64(5), object(4)
# memory usage: 73.2+ KB

# %%
df.pd.DataFrame({'a':[10,20,30],'b':[3,4,5],'c':[1,7,8]})
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df.pd.DataFrame({'a':[10,20,30],'b':[3,4,5],'c':[1,7,8]})
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'pd'

# %%
df.insert(1,'D','Python')

# %%
df
# Out:
#      PassengerId       D  Survived  \
# 0              1  Python         0
# 1              2  Python         1
# 2              3  Python         1
# 3              4  Python         1
# 4              5  Python         0
# ..           ...     ...       ...
# 886          887  Python         0
# 887          888  Python         1
# 888          889  Python         0
# 889          890  Python         1
# 890          891  Python         0
#
#                                                   Name  Gender  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[106], line 1
# ----> 1 df.insert(1,'F',['Python','a',6])
#       2 df
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4821, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
# -> 4821 value = self._sanitize_column(value)
#    4822 self._mgr.insert(loc, column, value)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4915, in DataFrame._sanitize_column(self, value)
#    4912     return _reindex_for_setitem(Series(value), self.index)
#    4914 if is_list_like(value):
# -> 4915     com.require_length_match(value, self.index)
#    4916 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\common.py:571, in require_length_match(data, index)
# ...
